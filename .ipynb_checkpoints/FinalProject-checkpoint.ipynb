# %% [markdown]
# # YearPredictionMSD Data Set
# ## Python for Data Analysis - Final Project
# ### CESAR Thomas, CHARRUEY Adrien - ESILV, A4, DIA 3

# %% [markdown]
# ### Library Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

## for statistical tests
import scipy
import statsmodels.formula.api as smf
import statsmodels.api as sm

## for machine learning
from sklearn import model_selection, preprocessing, feature_selection, ensemble, linear_model, metrics, decomposition

# %% [markdown]
# ### Data Set Import
# The data set can be downloaded here : https://archive.ics.uci.edu/ml/datasets/YearPredictionMSD

# %%
df = pd.read_csv(r'C:\Users\BgTxt\Documents\tamerelapute\YearPredictionMSD.txt',header=None)
df.head()
# Out:
#      0         1         2         3         4         5         6         7   \
# 0  2001  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905 -25.01202
# 1  2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777   8.76630
# 2  2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940  -3.27872
# 3  2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683   5.05097
# 4  2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409 -12.48207
#
#          8         9   ...        81         82        83        84        85  \
# 0 -12.23257   7.83089  ...  13.01620  -54.40548  58.99367  15.37344   1.11144
# 1  -0.92019  18.76548  ...   5.66812  -19.68073  33.04964  42.87836  -9.90378
# 2  -2.35035  16.07017  ...   3.03800   26.05866 -50.92779  10.93792  -0.07568
# 3 -10.34124   3.55005  ...  34.57337 -171.70734 -16.96705 -46.67617 -12.51516
# 4  -9.37636  12.63699  ...   9.92661  -55.95724  64.92712 -17.72522  -1.49237
#
#          86         87        88         89        90
# 0 -23.08793   68.40795  -1.82223  -27.46348   2.26327
# 1 -32.22788   70.49388  12.04941   58.43453  26.92061
# 2  43.20130 -115.00698  -0.05859   39.67068  -0.66345
# 3  82.58061  -72.08993   9.90558  199.62971  18.85382
# 4  -7.50035   51.76631   7.88713   55.66926  28.74903
#
# [5 rows x 91 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
df.describe()
# Out:
#                   0              1              2              3   \
# count  515345.000000  515345.000000  515345.000000  515345.000000
# mean     1998.397082      43.387126       1.289554       8.658347
# std        10.931046       6.067558      51.580351      35.268585
# min      1922.000000       1.749000    -337.092500    -301.005060
# 25%      1994.000000      39.954690     -26.059520     -11.462710
# 50%      2002.000000      44.258500       8.417850      10.476320
# 75%      2006.000000      47.833890      36.124010      29.764820
# max      2011.000000      61.970140     384.065730     322.851430
#
#                   4              5              6              7   \
# count  515345.000000  515345.000000  515345.000000  515345.000000
# mean        1.164124      -6.553601      -9.521975      -2.391089
# std        16.322790      22.860785      12.857751      14.571873
# min      -154.183580    -181.953370     -81.794290    -188.214000
# 25%        -8.487500     -20.666450     -18.440990     -10.780600
# 50%        -0.652840      -6.007770     -11.188390      -2.046670
# 75%         8.787540       7.741870      -2.388960       6.508580
# max       335.771820     262.068870     166.236890     172.402680
#
#                   8              9   ...             81             82  \
# count  515345.000000  515345.000000  ...  515345.000000  515345.000000
# mean       -1.793236       3.727876  ...      15.755406     -73.461500
# std         7.963827      10.582861  ...      32.099635     175.618889
# min       -72.503850    -126.479040  ...    -437.722030   -4402.376440
# 25%        -6.468420      -2.293660  ...      -1.812650    -139.555160
# 50%        -1.736450       3.822310  ...       9.171850     -53.090060
# 75%         2.913450       9.961820  ...      26.274480      13.478730
# max       126.741270     146.297950  ...     840.973380    4469.454870
#
#                   83             84             85             86  \
# count  515345.000000  515345.000000  515345.000000  515345.000000
# mean       41.542422      37.934119       0.315751      17.669213
# std       122.228799      95.050631      16.161764     114.427905
# min     -1810.689190   -3098.350310    -341.789120   -3168.924570
# 25%       -20.986900      -4.669540      -6.781590     -31.580610
# 50%        28.791060      33.623630       0.820840      15.598470
# 75%        89.661770      77.785800       8.470990      67.794960
# max      3210.701700    1734.079690     260.544900    3662.065650
#
#                   87             88             89             90
# count  515345.000000  515345.000000  515345.000000  515345.000000
# mean      -26.315336       4.458641      20.035136       1.329105
# std       173.977336      13.346557     185.558247      22.088576
# min     -4319.992320    -236.039260   -7458.378150    -381.424430
# 25%      -101.530300      -2.566090     -59.509270      -8.820210
# 50%       -21.204120       3.117640       7.759730       0.053050
# 75%        52.389330       9.967740      86.351610       9.679520
# max      2833.608950     463.419500    7393.398440     677.899630
#
# [8 rows x 91 columns]

# %% [markdown]
# We rename the first column of the dataframe

# %%
df.rename(columns={0:'year'}, inplace=True)

# %%
df.head()
# Out:
#    year         1         2         3         4         5         6         7  \
# 0  2001  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905 -25.01202
# 1  2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777   8.76630
# 2  2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940  -3.27872
# 3  2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683   5.05097
# 4  2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409 -12.48207
#
#           8         9  ...        81         82        83        84        85  \
# 0 -12.23257   7.83089  ...  13.01620  -54.40548  58.99367  15.37344   1.11144
# 1  -0.92019  18.76548  ...   5.66812  -19.68073  33.04964  42.87836  -9.90378
# 2  -2.35035  16.07017  ...   3.03800   26.05866 -50.92779  10.93792  -0.07568
# 3 -10.34124   3.55005  ...  34.57337 -171.70734 -16.96705 -46.67617 -12.51516
# 4  -9.37636  12.63699  ...   9.92661  -55.95724  64.92712 -17.72522  -1.49237
#
#          86         87        88         89        90
# 0 -23.08793   68.40795  -1.82223  -27.46348   2.26327
# 1 -32.22788   70.49388  12.04941   58.43453  26.92061
# 2  43.20130 -115.00698  -0.05859   39.67068  -0.66345
# 3  82.58061  -72.08993   9.90558  199.62971  18.85382
# 4  -7.50035   51.76631   7.88713   55.66926  28.74903
#
# [5 rows x 91 columns]

# %% [markdown]
# We check for null values :

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# We can see that there are no null values in the dataframe. We can proceed to the exploratory analysis.
# ### Exploratory Data Analysis

# %%
fig, ax = plt.subplots(figsize=(15,8))

ax.set_title('Distribution of songs per release year', fontsize=15)
variable = df['year']

sns.distplot(variable, hist=True, kde=True, kde_kws={"shade": True}, ax=ax)
des = df['year'].describe()
ax.axvline(des["25%"], ls='--')
ax.axvline(des["mean"], ls='--')
ax.axvline(des["75%"], ls='--')
ax.grid(True)

des = round(des).apply(lambda x: str(x))
box = '\n'.join(("min: "+des["min"], "25%: "+des["25%"], "mean: "+des["mean"], "75%: "+des["75%"], "max: "+des["max"]))
ax.text(0.20, 0.95, box, transform=ax.transAxes, fontsize=10, va='top', ha="right", bbox=dict(boxstyle='round', facecolor='white', alpha=1));
# Out:
# C:\Users\BgTxt\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We can see that there is a peak in the year 2000s. Unbalanced data like that could result in our models to predict only release years around the year 2000s. We might have to use downsampling to solve this problem.

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.bar(df.columns.map(str), df.mean().values)
ax.set_xlabel('Variables')
plt.xticks(rotation = 90)
plt.title('Mean of each variable of the dataset');

# %% [markdown]
# The year and variables from 14 to 24 have much greater means than the other variables. We will have to scale the data before using it for our models.

# %%
df_melted = pd.melt(df)

sns.set(rc={"figure.figsize":(20, 10)}) #width=3, #height=4
sns.boxplot(x='variable', y='value', data=df_melted);

# %% [markdown]
# We can see that there is a great number of major outliers for variables 14 to 90.

# %%
# Correlation between the release year and features
corr = df.corr()
fig, ax = plt.subplots(figsize=(10,10)) 
plt.title("Correlation matrix")
sns.heatmap(corr, square=True);

# %% [markdown]
# We focus on the correlation of the features to the year.

# %%
fig, ax = plt.subplots(figsize=(25,7)) 
sns.barplot(corr['year'][1:].index,corr['year'][1:].values)
plt.title('Correlation to year');
# Out:
# C:\Users\BgTxt\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Splitting the data set
# We split the data set into a training and a testing data set, before applying any pre-processing of the data,as it would otherwise put information from the testing set into the training set.
#
# We follow the instruction given on the data set page on the UCI Machine Learning Repository and split the data set this way :
#
# train: first 463,715 examples
#
# test: last 51,630 examples
#
# Which according to the website "avoids the 'producer effect' by making sure no song
# from a given artist ends up in both the train and test set."

# %%
df_train=df.iloc[:463715,:]
print(df_train.shape)
df_test=df.iloc[463715:,:]
print(df_test.shape)
# Out:
# (463715, 91)
# (51630, 91)

# %%
df_train.describe()
# Out:
#                 year              1              2              3  \
# count  463715.000000  463715.000000  463715.000000  463715.000000
# mean     1998.386095      43.385488       1.261091       8.650195
# std        10.939767       6.079139      51.613473      35.264750
# min      1922.000000       1.749000    -337.092500    -301.005060
# 25%      1994.000000      39.957540     -26.153810     -11.441920
# 50%      2002.000000      44.262570       8.371550      10.470520
# 75%      2006.000000      47.833650      36.143780      29.741165
# max      2011.000000      61.970140     384.065730     322.851430
#
#                    4              5              6              7  \
# count  463715.000000  463715.000000  463715.000000  463715.000000
# mean        1.130763      -6.512725      -9.565527      -2.384609
# std        16.334672      22.855820      12.836758      14.580245
# min      -154.183580    -181.953370     -81.794290    -188.214000
# 25%        -8.515155     -20.636960     -18.468705     -10.776340
# 50%        -0.691610      -5.992740     -11.208850      -2.047850
# 75%         8.756995       7.749590      -2.422590       6.515710
# max       289.527430     262.068870     119.815590     172.402680
#
#                    8              9  ...             81             82  \
# count  463715.000000  463715.000000  ...  463715.000000  463715.000000
# mean       -1.793722       3.714584  ...      15.743361     -73.067753
# std         7.961876      10.579241  ...      32.086356     175.376872
# min       -72.503850    -126.479040  ...    -437.722030   -4402.376440
# 25%        -6.461400      -2.303600  ...      -1.798085    -139.062035
# 50%        -1.735440       3.816840  ...       9.161360     -52.878010
# 75%         2.905130       9.950960  ...      26.248290      13.620660
# max       105.210280     146.297950  ...     840.973380    4469.454870
#
#                   83             84             85             86  \
# count  463715.000000  463715.000000  463715.000000  463715.000000
# mean       41.423976      37.780868       0.345259      17.599280
# std       121.794610      94.874474      16.153797     114.336522
# min     -1810.689190   -3098.350310    -341.789120   -3168.924570
# 25%       -20.918635      -4.711470      -6.758160     -31.563615
# 50%        28.709870      33.494550       0.828350      15.554490
# 75%        89.419995      77.674700       8.495715      67.743725
# max      3210.701700    1672.647100     260.544900    3662.065650
#
#                   87             88             89             90
# count  463715.000000  463715.000000  463715.000000  463715.000000
# mean      -26.364826       4.444985      19.739307       1.323326
# std       174.187892      13.320996     184.843503      22.045404
# min     -4319.992320    -236.039260   -7458.378150    -318.223330
# 25%      -101.396245      -2.572830     -59.598030      -8.813335
# 50%       -21.123570       3.111120       7.586950       0.052840
# 75%        52.299850       9.948955      86.203115       9.670740
# max      2833.608950     463.419500    7393.398440     600.766240
#
# [8 rows x 91 columns]

# %%
df_test.describe()
# Out:
#                year             1             2             3             4  \
# count  51630.000000  51630.000000  51630.000000  51630.000000  51630.000000
# mean    1998.495758     43.401835      1.545196      8.731564      1.463758
# std       10.852015      5.962572     51.281696     35.303265     16.212757
# min     1927.000000      6.697670   -303.172820   -245.410920    -89.217700
# 25%     1995.000000     39.929720    -25.184490    -11.600835     -8.230815
# 50%     2002.000000     44.229145      8.890255     10.548425     -0.319695
# 75%     2006.000000     47.836822     35.981468     29.940652      9.085015
# max     2010.000000     60.277240    275.044700    263.002620    335.771820
#
#                   5             6             7             8             9  \
# count  51630.000000  51630.000000  51630.000000  51630.000000  51630.000000
# mean      -6.920730     -9.130814     -2.449289     -1.788870      3.847252
# std       22.902284     13.038397     14.496472      7.981406     10.614668
# min     -131.846730    -57.980610   -113.116000    -57.871990    -72.142120
# 25%      -20.933628    -18.168130    -10.825130     -6.531265     -2.213935
# 50%       -6.123600    -11.018170     -2.038705     -1.746645      3.889485
# 75%        7.680063     -2.122810      6.456940      2.984270     10.051895
# max      146.915540    166.236890     83.602670    126.741270     88.007650
#
#        ...            81            82            83            84  \
# count  ...  51630.000000  51630.000000  51630.000000  51630.000000
# mean   ...     15.863589    -76.997938     42.606243     39.310543
# std    ...     32.218761    177.740419    126.057675     96.608422
# min    ...   -246.357820  -3129.093610  -1110.461140  -1744.646510
# 25%    ...     -1.941518   -143.866858    -21.597855     -4.348418
# 50%    ...      9.279585    -54.900645     29.508960     34.781505
# 75%    ...     26.487203     12.322653     91.861593     78.880403
# max    ...    504.320310   1745.814420   1710.525910   1734.079690
#
#                  85            86            87            88            89  \
# count  51630.000000  51630.000000  51630.000000  51630.000000  51630.000000
# mean       0.050725     18.297317    -25.870845      4.581295     22.692133
# std       16.230899    115.244623    172.075713     13.573491    191.839796
# min     -219.614190  -1774.001580  -2854.346800   -157.341220  -2506.955030
# 25%       -7.012528    -31.828520   -102.875242     -2.515942    -58.742800
# 50%        0.757470     16.069910    -21.931495      3.174520      9.395170
# 75%        8.278785     68.400735     53.173012     10.117640     87.555310
# max      169.214150   2010.117560   2032.431110    244.341800   6946.627670
#
#                  90
# count  51630.000000
# mean       1.381016
# std       22.472760
# min     -381.424430
# 25%       -8.882680
# 50%        0.054950
# 75%        9.758345
# max      677.899630
#
# [8 rows x 91 columns]

# %% [markdown]
# ### Scaling
# We scale all the features, not the target

# %%
# create the scaler 
ss = preprocessing.StandardScaler()

# create new dataframes to keep the non scaled ones
df_train_s=df_train.copy()
df_test_s=df_test.copy()

# apply the scaler to the dataframe subset 
df_train_s.iloc[:,1:] = ss.fit_transform(df_train_s.iloc[:,1:])
df_test_s.iloc[:,1:] = ss.transform(df_test_s.iloc[:,1:])

# %%
means = pd.DataFrame(list(zip(df_train.columns, df_train.mean(), df_test.mean())),
                   columns=['variable', 'train', 'test'])
means.drop(0, inplace=True)

means = pd.melt(means, id_vars="variable", var_name="dataframe", value_name="mean")

sns.catplot(x='variable', y='mean', hue='dataframe', data=means, kind='bar', height=8, aspect=1.7)
plt.xticks(rotation = 90)
plt.title('Mean of each feature in the training and testing dataframes before scaling');

# %%
means = pd.DataFrame(list(zip(df_train.columns, df_train_s.mean(), df_test_s.mean())),
                   columns=['variable', 'train scaled', 'test scaled'])
means.drop(0, inplace=True)

means = pd.melt(means, id_vars="variable", var_name="dataframe", value_name="mean")

sns.catplot(x='variable', y='mean', hue='dataframe', data=means, kind='bar', height=8, aspect=1.7)
plt.xticks(rotation = 90)
plt.title('Mean of each feature in the training and testing dataframes after scaling');

# %% [markdown]
# We can see that the mean of the scaled dataframes are very close to zero.

# %%
maxi = pd.DataFrame(list(zip(df_train.columns, df_train.max(), df_test.max())),
                   columns=['variable', 'train', 'test'])
maxi.drop(0, inplace=True)

maxi = pd.melt(maxi, id_vars="variable", var_name="dataframe", value_name="maximum")

sns.catplot(x='variable', y='maximum', hue='dataframe', data=maxi, kind='bar', height=8, aspect=1.7)
plt.xticks(rotation = 90)
plt.title('Maximum of each feature in the training and testing dataframes before scaling');

# %%
maxi = pd.DataFrame(list(zip(df_train.columns, df_train_s.max(), df_test_s.max())),
                   columns=['variable', 'train scaled', 'test scaled'])
maxi.drop(0, inplace=True)

maxi = pd.melt(maxi, id_vars="variable", var_name="dataframe", value_name="maximum")

sns.catplot(x='variable', y='maximum', hue='dataframe', data=maxi, kind='bar', height=8, aspect=1.7)
plt.xticks(rotation = 90)
plt.title('Maximum of each feature in the training and testing dataframes after scaling');

# %% [markdown]
# ## Downsampling

# %%
df_test_s['Decade'] = df_test_s.year.apply(lambda year : year-(year%10))
df_test_s=df_test_s[df_test_s.Decade>1940]


df_train_s['Decade'] = df_train_s.year.apply(lambda year : year-(year%10))
df_train_s=df_train_s[df_train_s.Decade>1940]


df_train_s.head()

#Downsampling by decade
min_samples = df_train_s.Decade.value_counts().min()
decades = df_train_s.Decade.unique()
df_sampled = pd.DataFrame(columns=df_train_s.columns)
for decade in decades:
    df_sampled = df_sampled.append(df_train_s[df_train_s.Decade==decade].sample(min_samples))
df_train_s=df_sampled

# %% [markdown]
# ### Principal Component Analysis (PCA)
# To reduce the dimensionnality of the data, we perform a PCA.

# %%
# Separate target and features
X_test = df_test_s.iloc[:,1:].values
y_test = df_test_s.iloc[:,0].values

X_train = df_train_s.iloc[:,1:].values
y_train = df_train_s.iloc[:,0].values


# Apply PCA
pca_test = decomposition.PCA(n_components=20).fit(X_test)
X_test_pca = pca_test.transform(X_test)
print('X_test.shape : ', X_test.shape, '\nX_test_pca.shape : ', X_test_pca.shape)

pca_train = decomposition.PCA(n_components=20).fit(X_train)
X_train_pca = pca_train.transform(X_train)
print('X_train.shape : ', X_train.shape, '\nX_train_pca.shape : ', X_train_pca.shape)


# Rename columns of the new dataframes
cols = ['year']
for m in range(1, X_train_pca.shape[1]+1):
    cols.append("PrincComp{}".format(m))

    
# We re concatenate X and y
df_test_pca = pd.DataFrame(np.append(y_test.reshape(y_test.shape[0],1), X_test_pca, axis=1), columns=cols)
print('df_test_pca.shape : ', df_test_pca.shape)

df_train_pca = pd.DataFrame(np.append(y_train.reshape(y_train.shape[0],1), X_train_pca, axis=1), columns=cols)
print('df_train_pca.shape : ', df_train_pca.shape)
df_train_pca.head()
# Out:
# X_test.shape :  (51536, 91)
# X_test_pca.shape :  (51536, 20)
# X_train.shape :  (19789, 91)
# X_train_pca.shape :  (19789, 20)
# df_test_pca.shape :  (51536, 21)
# df_train_pca.shape :  (19789, 21)
#    year PrincComp1 PrincComp2 PrincComp3 PrincComp4 PrincComp5 PrincComp6  \
# 0  2004  -19.52913   7.147711  -2.653198  -0.781735   4.973678    0.00567
# 1  2003 -20.135665  -2.674458   -0.41142   2.651968  -0.714284  -0.641893
# 2  2008 -20.052558  -0.527564   2.301153   4.285469  -0.300567  -0.887231
# 3  2000 -20.085573  -2.281144   0.159119    1.65609   1.407446  -0.703973
# 4  2002 -20.039315   0.061619   1.436961  -0.195107  -0.074766  -0.459277
#
#   PrincComp7 PrincComp8 PrincComp9  ... PrincComp11 PrincComp12 PrincComp13  \
# 0  -0.375715  -0.404549  -1.105307  ...    2.283055   -0.983381   -0.480682
# 1  -0.732462  -0.273178  -0.115399  ...     -0.5478    0.213498    -0.99567
# 2  -1.149641   1.193215    0.63585  ...    0.819067     1.53459    1.226707
# 3  -0.401369   0.238512   0.261746  ...   -0.627571    0.492469   -1.047182
# 4  -2.004123   0.694094  -0.754366  ...   -0.075836    0.126334   -0.556276
#
#   PrincComp14 PrincComp15 PrincComp16 PrincComp17 PrincComp18 PrincComp19  \
# 0   -0.233424      0.6356    1.357166   -1.644829   -0.203657    1.154506
# 1   -0.263142     0.42241   -0.571649    0.581008    0.274751    0.100572
# 2    -1.19541    0.256968    0.912159   -2.296459    0.190795   -0.413623
# 3    0.100248    0.065828   -0.137196    0.380875   -0.236553    0.380715
# 4   -1.984106   -0.797991   -0.248726    0.272194   -0.185296   -0.688411
#
#   PrincComp20
# 0   -0.337417
# 1     0.22381
# 2     0.40329
# 3    0.497263
# 4   -0.334928
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Metrics :
#
# We create a function that will return a tuple of several metrics.

# %%
def metric(modelName, y_test, y_pred):
    explained_variance=metrics.explained_variance_score(y_test, y_pred)
    mean_absolute_error=metrics.mean_absolute_error(y_test, y_pred) 
    mse=metrics.mean_squared_error(y_test, y_pred) 
    median_absolute_error=metrics.median_absolute_error(y_test, y_pred)
    r2=metrics.r2_score(y_test, y_pred)
    r2_adj = 1-((1-r2)* (len(y_test)-1)/(len(y_test)-91))
    rmse = np.sqrt(mse)

    print('explained_variance: ', round(explained_variance,4))    
    print('R^2: ', round(r2,4))
    print('R^2adj: ', round(r2_adj,4))
    print('MAE: ', round(mean_absolute_error,4))
    print('MSE: ', round(mse,4))
    print('RMSE: ', round(rmse,4))
    
    return (modelName, explained_variance, mean_absolute_error, mse, rmse, r2, r2_adj)

# %% [markdown]
# We create a dataframe that we will fill with the metrics of each model we try.

# %%
df_metrics = pd.DataFrame(columns=['Model','ExplainedVariance', 'MeanAbsoluteError', 'MeanSquaredError', 'RootMeanSquaredError', 'R^2','R^2adjusted'])
df_metrics
# Out:
# Empty DataFrame
# Columns: [Model, ExplainedVariance, MeanAbsoluteError, MeanSquaredError, RootMeanSquaredError, R^2, R^2adjusted]
# Index: []

# %% [markdown]
# ### Testing a lot of modelling methods

# %%
X_test = df_test_s.iloc[:,1:]
y_test = df_test_s.iloc[:,0]

X_train = df_train_s.iloc[:,1:]
y_train = df_train_s.iloc[:,0]

# %%
def get_sklearn_algorithms(verbose = False):
    from collections import defaultdict
    import importlib
    import sklearn
    algos = defaultdict(list)
    if verbose : print (dir(sklearn))
    for nom_module in dir(sklearn):    
        if verbose : print (nom_module)
        try:
            to_import = "sklearn.%s"%nom_module
            module    = importlib.import_module(to_import)
            for nom_fonction in dir(module):
                fonction = getattr(module, nom_fonction)
                if hasattr(fonction, "fit"):
                    if verbose : print (" nom algorithme  = ", nom_fonction)
                    algos[nom_module].append(fonction)                                            
        except Exception as e:
            if verbose : print( e)
        if verbose: print ("="*30)
    return algos

# %%
algos = get_sklearn_algorithms()
algos.pop("decomposition")
algos.pop("dummy")
algos.pop("feature_selection")
# Out:
# [sklearn.feature_selection._univariate_selection.GenericUnivariateSelect,
#  sklearn.feature_selection._rfe.RFE,
#  sklearn.feature_selection._rfe.RFECV,
#  sklearn.feature_selection._univariate_selection.SelectFdr,
#  sklearn.feature_selection._univariate_selection.SelectFpr,
#  sklearn.feature_selection._from_model.SelectFromModel,
#  sklearn.feature_selection._univariate_selection.SelectFwe,
#  sklearn.feature_selection._univariate_selection.SelectKBest,
#  sklearn.feature_selection._univariate_selection.SelectPercentile,
#  sklearn.feature_selection._sequential.SequentialFeatureSelector,
#  sklearn.feature_selection._variance_threshold.VarianceThreshold]

# %%
for key in algos.keys():
    print ("\n===>",key)
    algos_ = []
    for algo in algos[key]:
        classe_algo = str(algo)
        nom_algo    = classe_algo[str(classe_algo).rfind(".")+1:str(classe_algo).rfind("'")]
        algos_.append(nom_algo)
    print (",".join(algos_))
# Out:
# ===> ensemble
# AdaBoostClassifier,AdaBoostRegressor,BaggingClassifier,BaggingRegressor,ExtraTreesClassifier,ExtraTreesRegressor,GradientBoostingClassifier,GradientBoostingRegressor,IsolationForest,RandomForestClassifier,RandomForestRegressor,RandomTreesEmbedding,StackingClassifier,StackingRegressor,VotingClassifier,VotingRegressor
#
# ===> linear_model
# ARDRegression,BayesianRidge,ElasticNet,ElasticNetCV,GammaRegressor,HuberRegressor,Lars,LarsCV,Lasso,LassoCV,LassoLars,LassoLarsCV,LassoLarsIC,LinearRegression,LogisticRegression,LogisticRegressionCV,MultiTaskElasticNet,MultiTaskElasticNetCV,MultiTaskLasso,MultiTaskLassoCV,OrthogonalMatchingPursuit,OrthogonalMatchingPursuitCV,PassiveAggressiveClassifier,PassiveAggressiveRegressor,Perceptron,PoissonRegressor,RANSACRegressor,Ridge,RidgeCV,RidgeClassifier,RidgeClassifierCV,SGDClassifier,SGDRegressor,TheilSenRegressor,TweedieRegressor
#
# ===> model_selection
# GridSearchCV,RandomizedSearchCV
#
# ===> neighbors
# KNeighborsClassifier,KNeighborsRegressor,KNeighborsTransformer,KernelDensity,LocalOutlierFactor,NearestCentroid,NearestNeighbors,NeighborhoodComponentsAnalysis,RadiusNeighborsClassifier,RadiusNeighborsRegressor,RadiusNeighborsTransformer
#
# ===> preprocessing
# Binarizer,FunctionTransformer,KBinsDiscretizer,KernelCenterer,LabelBinarizer,LabelEncoder,MaxAbsScaler,MinMaxScaler,MultiLabelBinarizer,Normalizer,OneHotEncoder,OrdinalEncoder,PolynomialFeatures,PowerTransformer,QuantileTransformer,RobustScaler,StandardScaler
#
# ===> svm
# LinearSVC,LinearSVR,NuSVC,NuSVR,OneClassSVM,SVC,SVR,pyd
#
# ===> tree
# BaseDecisionTree,DecisionTreeClassifier,DecisionTreeRegressor,ExtraTreeClassifier,ExtraTreeRegressor

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
performances               = {}
modeles_a_tester           = []
best=[]
classes_de_models_a_tester = algos.keys()
best_algorithm = 0
best_perf = 0
for classe_de_models in classes_de_models_a_tester:
    modeles_a_tester.extend(algos[classe_de_models])
    
for pointeur_vers_algo in modeles_a_tester:
    try:
        algorithme = pointeur_vers_algo()
        doc        = algorithme.__doc__
        name       = doc[:min(doc.find(":"), 25)].strip()
        print (name)
        algorithme.fit(X_train, y_train)
        performance = algorithme.score(X_test, y_test)
        print (performance)
        if performance >  best_perf:
            best_algorithm = algorithme
            best_perf = performance
        if performance > 0.92:
            best.append(name)
            
        if 0<performance and performance<1:
            performances[name] = [performance]
    except Exception as e:
        if "label" in str(e): print ("Algo de classification")
        else                : print (str(e)[:50])
    print ("="*30)
# Out:
# An AdaBoost classifier.
# Algo de classification
# ==============================
# An AdaBoost regressor.
# 0.9337622925305974
# ==============================
# A Bagging classifier.
# Algo de classification
# ==============================
# A Bagging regressor.
# 0.9315636734335724
# ==============================
# An extra-trees class
# Algo de classification
# ==============================
# An extra-trees regre
# 0.9373255411781398
# ==============================
# Gradient Boosting for cla
# Algo de classification
# ==============================
# Gradient Boosting for reg
# 0.9354849514737074
# ==============================
# Isolation Forest Alg
# 'IsolationForest' object has no attribute 'score'
# ==============================
# A random forest clas
# Algo de classification
# ==============================
# A random forest regr
# 0.9373250740892723
# ==============================
# An ensemble of total
# 'RandomTreesEmbedding' object has no attribute 'sc
# ==============================
# __init__() missing 1 required positional argument:
# ==============================
# __init__() missing 1 required positional argument:
# ==============================
# __init__() missing 1 required positional argument:
# ==============================
# __init__() missing 1 required positional argument:
# ==============================
# Bayesian ARD regression.
# 0.9089827215432802
# ==============================
# Bayesian ridge regression
# 0.908950660464246
# ==============================
# Linear regression with co
# 0.9086775340296758
# ==============================
# Elastic Net model with it
# 0.9089539540731356
# ==============================
# Generalized Linear Model
# -1.7569271739149874
# ==============================
# Linear regression model t
# C:\Users\BgTxt\anaconda3\lib\site-packages\sklearn\linear_model\_glm\link.py:90: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\BgTxt\anaconda3\lib\site-packages\sklearn\linear_model\_glm\link.py:93: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\BgTxt\anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: invalid value encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# C:\Users\BgTxt\anaconda3\lib\site-packages\sklearn\linear_model\_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 0.912670438102523
# ==============================
# Least Angle Regression mo
# 0.9079534947791327
# ==============================
# Cross-validated Least Ang
# 0.9074050510530138
# ==============================
# Linear Model trained with
# 0.9086350961079037
# ==============================
# Lasso linear model with i
# 0.9093311079664818
# ==============================
# Lasso model fit with Leas
# -1.750402265391541
# ==============================
# Cross-validated Lasso, us
# 0.9074050510530138
# ==============================
# Lasso model fit with Lars
# 0.9066524265210805
# ==============================
# Ordinary least squar
# 0.9087903952939954
# ==============================
# Logistic Regression
# Algo de classification
# ==============================
# Logistic Regression CV (a
# Algo de classification
# ==============================
# Multi-task ElasticNet mod
# For mono-task outputs, use ElasticNet
# ==============================
# Multi-task L1/L2 ElasticN
# For mono-task outputs, use ElasticNetCVCV
# ==============================
# Multi-task Lasso model tr
# For mono-task outputs, use ElasticNet
# ==============================
# Multi-task Lasso model tr
# For mono-task outputs, use LassoCVCV
# ==============================
# Orthogonal Matching Pursu
# 0.908864766496988
# ==============================
# Cross-validated Orthogona
# 0.9088971118108006
# ==============================
# Passive Aggressive Classi
# Algo de classification
# ==============================
# Passive Aggressive Regres
# 0.7954615206788757
# ==============================
# Perceptron
#
#     Read more
# Algo de classification
# ==============================
# Generalized Linear Model
# C:\Users\BgTxt\anaconda3\lib\site-packages\sklearn\linear_model\_glm\link.py:90: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\BgTxt\anaconda3\lib\site-packages\sklearn\linear_model\_glm\link.py:93: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\BgTxt\anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: invalid value encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# C:\Users\BgTxt\anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:315: RuntimeWarning: invalid value encountered in add
#   dev = 2 * (xlogy(y, y/y_pred) - y + y_pred)
# C:\Users\BgTxt\anaconda3\lib\site-packages\sklearn\linear_model\_glm\glm.py:287: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# -1.7536745790346067
# ==============================
# RANSAC (RANdom SAmple Con
# 0.9033788887004426
# ==============================
# Linear least squares with
# 0.9087909420819331
# ==============================
# Ridge regression with bui
# 0.9087957950691953
# ==============================
# Classifier using Ridge re
# Algo de classification
# ==============================
# Ridge classifier with bui
# Algo de classification
# ==============================
# Linear classifiers (SVM,
# Algo de classification
# ==============================
# Linear model fitted by mi
# -1.0658127119300162e+27
# ==============================
# Theil-Sen Estimator
# 0.8975180091805861
# ==============================
# Generalized Linear Model
# C:\Users\BgTxt\anaconda3\lib\site-packages\sklearn\linear_model\_glm\glm.py:287: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# 0.9085799017469859
# ==============================
# __init__() missing 2 required positional arguments
# ==============================
# __init__() missing 2 required positional arguments
# ==============================
# Classifier implementing t
# Algo de classification
# ==============================
# Regression based on k-nea
# 0.9248469986492132
# ==============================
# Transform X into a (weigh
# 'KNeighborsTransformer' object has no attribute 's
# ==============================
# Kernel Density Estimation
# -6082482.994640239
# ==============================
# Unsupervised Outlier Dete
# 'LocalOutlierFactor' object has no attribute 'scor
# ==============================
# Nearest centroid classifi
# Algo de classification
# ==============================
# Unsupervised learner for
# 'NearestNeighbors' object has no attribute 'score'
# ==============================
# Neighborhood Components A
# Algo de classification
# ==============================
# Classifier implementing a
# Algo de classification
# ==============================
# Regression based on neigh
# ufunc 'isnan' not supported for the input types, a
# ==============================
# Transform X into a (weigh
# 'RadiusNeighborsTransformer' object has no attribu
# ==============================
# Binarize data (set featur
# 'Binarizer' object has no attribute 'score'
# ==============================
# Constructs a transformer
# 'FunctionTransformer' object has no attribute 'sco
# ==============================
# Bin continuous data
# 'KBinsDiscretizer' object has no attribute 'score'
# ==============================
# Center a kernel matrix.
# Kernel matrix must be a square matrix. Input is a
# ==============================
# Binarize labels in a one-
# fit() takes 2 positional arguments but 3 were give
# ==============================
# Encode target labels with
# fit() takes 2 positional arguments but 3 were give
# ==============================
# Scale each feature by its
# 'MaxAbsScaler' object has no attribute 'score'
# ==============================
# Transform features by sca
# 'MinMaxScaler' object has no attribute 'score'
# ==============================
# Transform between iterabl
# fit() takes 2 positional arguments but 3 were give
# ==============================
# Normalize samples individ
# 'Normalizer' object has no attribute 'score'
# ==============================
# Encode categorical f
# 'OneHotEncoder' object has no attribute 'score'
# ==============================
# Encode categorical f
# 'OrdinalEncoder' object has no attribute 'score'
# ==============================
# Generate polynomial and i
# 'PolynomialFeatures' object has no attribute 'scor
# ==============================
# Apply a power transform f
# 'PowerTransformer' object has no attribute 'score'
# ==============================
# Transform features using
# 'QuantileTransformer' object has no attribute 'sco
# ==============================
# Scale features using stat
# 'RobustScaler' object has no attribute 'score'
# ==============================
# Standardize features by r
# 'StandardScaler' object has no attribute 'score'
# ==============================
# Linear Support Vector Cla
# Algo de classification
# ==============================
# Linear Support Vector Reg
# C:\Users\BgTxt\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# 0.7852141674153098
# ==============================
# Nu-Support Vector Classif
# Algo de classification
# ==============================
# Nu Support Vector Regress
# -0.9188471345342692
# ==============================
# Unsupervised Outlier Dete
# 'OneClassSVM' object has no attribute 'score'
# ==============================
# C-Support Vector Classifi
# Algo de classification
# ==============================
# Epsilon-Support Vector Re
# -0.6569936651565083
# ==============================
# 'module' object is not callable
# ==============================
# Can't instantiate abstract class BaseDecisionTree
# ==============================
# A decision tree classifie
# Algo de classification
# ==============================
# A decision tree regressor
# 0.8746207150925501
# ==============================
# An extremely randomized t
# Algo de classification
# ==============================
# An extremely randomized t
# 0.8732745909259464
# ==============================

# %%
best_algorithm, best_perf
# Out:
# (ExtraTreesRegressor(), 0.9373255411781398)

# %%
best
# Out:
# ['An AdaBoost regressor.',
#  'A Bagging regressor.',
#  'An extra-trees regre',
#  'Gradient Boosting for reg',
#  'A random forest regr',
#  'Regression based on k-nea']

# %% [markdown]
# ### AdaBoost Regression

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor().fit(X_train,y_train)
 

y_pred_ada = np.round(ada.predict(df_test_s.iloc[:,1:]),0)
pd.DataFrame(y_pred_ada, columns=['year']).head()
# Out:
#      year
# 0  2005.0
# 1  2005.0
# 2  2005.0
# 3  2005.0
# 4  2005.0

# %%
df_metrics = df_metrics.append(dict(zip(df_metrics.columns,metric('AdaBoost Regression', y_test, y_pred_ada))), ignore_index=True)
# Out:
# explained_variance:  0.9337
# R^2:  0.9336
# R^2adj:  0.9335
# MAE:  2.2836
# MSE:  7.3898
# RMSE:  2.7184

# %% [markdown]
# ### Bagging Regression

# %%
from sklearn.ensemble import BaggingRegressor
bagg = BaggingRegressor().fit(X_train,y_train)
 

y_pred_bagg = np.round(bagg.predict(df_test_s.iloc[:,1:]),0)
pd.DataFrame(y_pred_bagg, columns=['year']).head()
# Out:
#      year
# 0  2006.0
# 1  2005.0
# 2  2005.0
# 3  2005.0
# 4  2005.0

# %%
df_metrics = df_metrics.append(dict(zip(df_metrics.columns,metric('Bagging Regression', y_test, y_pred_bagg))), ignore_index=True)
# Out:
# explained_variance:  0.9309
# R^2:  0.9309
# R^2adj:  0.9308
# MAE:  2.2785
# MSE:  7.6894
# RMSE:  2.773

# %% [markdown]
# ### Extra-trees Regression

# %%
from sklearn.ensemble import ExtraTreesRegressor
extra = ExtraTreesRegressor().fit(X_train,y_train)
 

y_pred_extra = np.round(extra.predict(df_test_s.iloc[:,1:]),0)
pd.DataFrame(y_pred_extra, columns=['year']).head()
# Out:
#      year
# 0  2005.0
# 1  2005.0
# 2  2005.0
# 3  2005.0
# 4  2005.0

# %%
df_metrics = df_metrics.append(dict(zip(df_metrics.columns,metric('Extra-trees Regression', y_test, y_pred_extra))), ignore_index=True)
# Out:
# explained_variance:  0.9367
# R^2:  0.9366
# R^2adj:  0.9365
# MAE:  2.2063
# MSE:  7.0502
# RMSE:  2.6552

# %% [markdown]
# ### Gradient Boosting for Regression

# %%
from sklearn.ensemble import GradientBoostingRegressor
grad = GradientBoostingRegressor().fit(X_train,y_train)
 

y_pred_grad = np.round(grad.predict(df_test_s.iloc[:,1:]),0)
pd.DataFrame(y_pred_grad, columns=['year']).head()
# Out:
#      year
# 0  2005.0
# 1  2005.0
# 2  2005.0
# 3  2005.0
# 4  2005.0

# %%
df_metrics = df_metrics.append(dict(zip(df_metrics.columns,metric('Gradient Boosting for Regression', y_test, y_pred_grad))), ignore_index=True)
# Out:
# explained_variance:  0.9349
# R^2:  0.9349
# R^2adj:  0.9347
# MAE:  2.2539
# MSE:  7.2487
# RMSE:  2.6923

# %% [markdown]
# ### Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor().fit(X_train,y_train)
 

y_pred_forest = np.round(forest.predict(df_test_s.iloc[:,1:]),0)
pd.DataFrame(y_pred_forest, columns=['year']).head()
# Out:
#      year
# 0  2004.0
# 1  2005.0
# 2  2006.0
# 3  2005.0
# 4  2005.0

# %%
df_metrics = df_metrics.append(dict(zip(df_metrics.columns,metric('Random Forest Regression', y_test, y_pred_forest))), ignore_index=True)
# Out:
# explained_variance:  0.9365
# R^2:  0.9365
# R^2adj:  0.9364
# MAE:  2.208
# MSE:  7.0681
# RMSE:  2.6586

# %% [markdown]
# ### Metrics results

# %%
df_metrics
# Out:
#                               Model  ExplainedVariance  MeanAbsoluteError  \
# 0               AdaBoost Regression           0.933700           2.283627
# 1                Bagging Regression           0.930915           2.278485
# 2            Extra-trees Regression           0.936671           2.206322
# 3  Gradient Boosting for Regression           0.934882           2.253861
# 4          Random Forest Regression           0.936507           2.208010
#
#    MeanSquaredError  RootMeanSquaredError       R^2  R^2adjusted
# 0          7.389805              2.718420  0.933585     0.933469
# 1          7.689421              2.772981  0.930892     0.930771
# 2          7.050159              2.655214  0.936637     0.936526
# 3          7.248739              2.692348  0.934853     0.934739
# 4          7.068108              2.658591  0.936476     0.936365

# %% [markdown]
# ### Graph

# %%
# Scatterplots
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(13,10))

# AdaBoost Regression
ax[0,0].scatter(y_test, y_pred_ada)
ax[0,0].set_xlabel('actual release year')
ax[0,0].set_ylabel('predicted release year')

lineStart = min(y_test.min(), y_pred_ada.min())
lineEnd = max(y_test.max(), y_pred_ada.max()) 
ax[0,0].plot([lineStart, lineEnd], [lineStart, lineEnd], '-', color = 'r', label = 'y=x')
ax[0,0].set_title('Scatterplot of the predictions vs actual release years with the AdaBoost Regression');


# Bagging Regression
ax[0,1].scatter(y_test, y_pred_bagg)
ax[0,1].set_xlabel('actual release year')
ax[0,1].set_ylabel('predicted release year')

lineStart = min(y_test.min(), y_pred_bagg.min())
lineEnd = max(y_test.max(), y_pred_bagg.max()) 
ax[0,1].plot([lineStart, lineEnd], [lineStart, lineEnd], '-', color = 'r', label = 'y=x')
ax[0,1].set_title('Scatterplot of the predictions vs actual release years with the Bagging Regression');


# Extra-trees Regression
ax[1,0].scatter(y_test, y_pred_extra)
ax[1,0].set_xlabel('actual release year')
ax[1,0].set_ylabel('predicted release year')

lineStart = min(y_test.min(), y_pred_extra.min())
lineEnd = max(y_test.max(), y_pred_extra.max()) 
ax[1,0].plot([lineStart, lineEnd], [lineStart, lineEnd], '-', color = 'r', label = 'y=x')
ax[1,0].set_title('Scatterplot of the predictions vs actual release years with the Extra-trees Regression');


# Gradient Boosting for Regression
ax[1,1].scatter(y_test, y_pred_grad)
ax[1,1].set_xlabel('actual release year')
ax[1,1].set_ylabel('predicted release year')

lineStart = min(y_test.min(), y_pred_grad.min())
lineEnd = max(y_test.max(), y_pred_grad.max()) 
ax[1,1].plot([lineStart, lineEnd], [lineStart, lineEnd], '-', color = 'r', label = 'y=x')
ax[1,1].set_title('Scatterplot of the predictions vs actual release years with the Gradient Boosting for Regression');

# Random Forest Regression
ax[2,0].scatter(y_test, y_pred_forest)
ax[2,0].set_xlabel('actual release year')
ax[2,0].set_ylabel('predicted release year')

lineStart = min(y_test.min(), y_pred_forest.min())
lineEnd = max(y_test.max(), y_pred_forest.max()) 
ax[2,0].plot([lineStart, lineEnd], [lineStart, lineEnd], '-', color = 'r', label = 'y=x')
ax[2,0].set_title('Scatterplot of the predictions vs actual release years with the Random Forest Regression');


plt.legend()
plt.tight_layout()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, sharex=True, sharey=True, figsize=(15,8))
fig.suptitle('Distribution of songs per release year', fontsize=15)

sns.distplot(y_test, hist=True, kde=True, ax=ax[0,0])
ax[0,0].set_title('y_test (true values)')

sns.distplot(y_pred_ada, hist=True, kde=True, ax=ax[0,1]);
ax[0,1].set_title('y_pred (predictions) with the AdaBoost Regression')

sns.distplot(y_pred_bagg, hist=True, kde=True, ax=ax[1,0]);
ax[1,0].set_title('y_pred (predictions) with the Bagging Regression')

sns.distplot(y_pred_extra, hist=True, kde=True, ax=ax[1,1]);
ax[1,1].set_title('y_pred (predictions) with the Extra-trees Regression')

sns.distplot(y_pred_grad, hist=True, kde=True, ax=ax[2,0]);
ax[2,0].set_title('y_pred (predictions) with the Gradient Boosting for Regression')

sns.distplot(y_pred_forest, hist=True, kde=True, ax=ax[2,1]);
ax[2,1].set_title('y_pred (predictions) with the Random Forest Regression')


plt.tight_layout()
# Out:
# C:\Users\BgTxt\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\BgTxt\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\BgTxt\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\BgTxt\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\BgTxt\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\BgTxt\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
